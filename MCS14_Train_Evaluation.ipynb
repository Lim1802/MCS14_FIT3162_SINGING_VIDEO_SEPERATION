# %% [markdown]
# # MCS14
# ## Training the music separation model

# %%
# @title 1. Install Dependencies
# %%capture
# 1. Setup and install dependencies
# !git clone https://github.com/Lim1802/MCS14_FIT3162_SINGING_VIDEO_SEPERATION.git
# %cd /content/MCS14_FIT3162_SINGING_VIDEO_SEPERATION/demucs
# !pip install -r requirements.txt

# Install soundtouch
# !sudo apt-get update
# !sudo apt-get install -y libsoundtouch-dev
# !sudo apt-get install -y soundstretch

# %%
# @title 2. Mount Google Drive (For training checkpoints and logs)
# 2. Mount Google Drive (for dataset storage and model checkpoints)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title 3. Update paths to your dataset (Need to manually change)

#@markdown Dataset path (Assuming you uploaded the dataset to My Drive) & (Change "musdb18hq" to your dataset name)
dataset_path = '/content/drive/MyDrive/musdb18hq' #@param ["snippets:","/content/drive/MyDrive/musdb18hq","/content/drive/MyDrive/<your dataset name>"]{allow-input: true}
# 4. Update paths in configuration files
# !sed -i "s|^  musdb:.*|  musdb: {dataset_path}|" conf/config.yaml
# !sed -i 's|dir: outputs|dir: /content/drive/MyDrive/demucs_outputs|' conf/config.yaml
# Use a better architecture
# !sed -i 's|model: demucs|model: hdemucs|' conf/config.yaml

# %%
# @title 4. Set up Dora XP repository
# %%capture
# !tar xvf outputs.tar.gz

# %%
# @title 5.1 Start training the model! (Hyper-Params will be further explained in our final report, for now just run this) (10 epochs will approximately take 10 hours)
# !dora run -d \
    batch_size=16 \
    demucs.channels=32 \
    demucs.depth=4 \
    dset.segment=5 \
    misc.num_workers=2 \
    optim.lr=5e-4 \
    epochs=20
# Out:
# Executor: Starting 1 worker processes for DDP.
# /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [10-12 17:17:09][demucs.train][INFO] - For logs, checkpoints and samples check /content/drive/MyDrive/demucs_outputs/xps/d7014c1b
# [10-12 17:17:09][dora.distrib][INFO] - world_size is 1, skipping init.
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [01:57<00:00,  1.18s/it]
# [10-12 17:19:24][demucs.train][INFO] - train/valid set size: 18884 14
# [10-12 17:19:24][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 17:19:24][demucs.solver][INFO] - Training...
# [10-12 17:43:52][demucs.solver][INFO] - Train | Epoch 1 | 295/1180 | 0.20 it/sec | Loss 0.1966 | Reco 0.1966 | Grad 0.0488
# [10-12 17:59:51][demucs.solver][INFO] - Train | Epoch 1 | 590/1180 | 0.24 it/sec | Loss 0.1805 | Reco 0.1805 | Grad 0.0604
# [10-12 18:15:57][demucs.solver][INFO] - Train | Epoch 1 | 885/1180 | 0.26 it/sec | Loss 0.1713 | Reco 0.1713 | Grad 0.0637
# [10-12 18:32:00][demucs.solver][INFO] - Train Summary | Epoch 1 | Loss=0.1652 | Reco=0.1652 | Grad=0.0657
# [10-12 18:32:00][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 18:32:00][demucs.solver][INFO] - Cross validation...
# [10-12 18:32:22][demucs.solver][INFO] - Valid | Epoch 1 | 3/14 | 0.18 it/sec | Loss 0.2144 | Reco 0.2144 | Nsdr 3.597
# [10-12 18:32:30][demucs.solver][INFO] - Valid | Epoch 1 | 6/14 | 0.23 it/sec | Loss 0.2214 | Reco 0.2214 | Nsdr 3.479
# [10-12 18:32:37][demucs.solver][INFO] - Valid | Epoch 1 | 9/14 | 0.27 it/sec | Loss 0.2208 | Reco 0.2208 | Nsdr 3.242
# [10-12 18:32:43][demucs.solver][INFO] - Valid | Epoch 1 | 12/14 | 0.30 it/sec | Loss 0.2149 | Reco 0.2149 | Nsdr 3.614
# [10-12 18:32:45][demucs.solver][INFO] - Valid Summary | Epoch 1 | Loss=0.2217 | Reco=0.2217 | Nsdr=3.506 | Best=0.2217 | Bname=main
# [10-12 18:32:45][demucs.solver][INFO] - New best valid loss 0.2217
# [10-12 18:32:50][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 18:32:50][demucs.solver][INFO] - Training...
# [10-12 18:48:54][demucs.solver][INFO] - Train | Epoch 2 | 295/1180 | 0.31 it/sec | Loss 0.1416 | Reco 0.1416 | Grad 0.0682
# [10-12 19:04:38][demucs.solver][INFO] - Train | Epoch 2 | 590/1180 | 0.31 it/sec | Loss 0.1417 | Reco 0.1417 | Grad 0.0671
# [10-12 19:20:52][demucs.solver][INFO] - Train | Epoch 2 | 885/1180 | 0.31 it/sec | Loss 0.1400 | Reco 0.1400 | Grad 0.0666
# [10-12 19:36:50][demucs.solver][INFO] - Train Summary | Epoch 2 | Loss=0.1388 | Reco=0.1388 | Grad=0.0665
# [10-12 19:36:50][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 19:36:50][demucs.solver][INFO] - Cross validation...
# [10-12 19:37:04][demucs.solver][INFO] - Valid | Epoch 2 | 3/14 | 0.28 it/sec | Loss 0.2039 | Reco 0.2039 | Nsdr 3.957
# [10-12 19:37:13][demucs.solver][INFO] - Valid | Epoch 2 | 6/14 | 0.31 it/sec | Loss 0.2068 | Reco 0.2068 | Nsdr 4.014
# [10-12 19:37:19][demucs.solver][INFO] - Valid | Epoch 2 | 9/14 | 0.34 it/sec | Loss 0.2037 | Reco 0.2037 | Nsdr 3.851
# [10-12 19:37:26][demucs.solver][INFO] - Valid | Epoch 2 | 12/14 | 0.36 it/sec | Loss 0.1997 | Reco 0.1997 | Nsdr 4.149
# [10-12 19:37:28][demucs.solver][INFO] - Valid Summary | Epoch 2 | Loss=0.2076 | Reco=0.2076 | Nsdr=4.002 | Best=0.2076 | Bname=main
# [10-12 19:37:28][demucs.solver][INFO] - New best valid loss 0.2076
# [10-12 19:37:32][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 19:37:32][demucs.solver][INFO] - Training...
# [10-12 19:53:37][demucs.solver][INFO] - Train | Epoch 3 | 295/1180 | 0.31 it/sec | Loss 0.1318 | Reco 0.1318 | Grad 0.0661
# [10-12 20:09:37][demucs.solver][INFO] - Train | Epoch 3 | 590/1180 | 0.31 it/sec | Loss 0.1312 | Reco 0.1312 | Grad 0.0649
# [10-12 20:25:36][demucs.solver][INFO] - Train | Epoch 3 | 885/1180 | 0.31 it/sec | Loss 0.1296 | Reco 0.1296 | Grad 0.0634
# [10-12 20:41:35][demucs.solver][INFO] - Train Summary | Epoch 3 | Loss=0.1291 | Reco=0.1291 | Grad=0.0644
# [10-12 20:41:35][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 20:41:35][demucs.solver][INFO] - Cross validation...
# [10-12 20:41:50][demucs.solver][INFO] - Valid | Epoch 3 | 3/14 | 0.27 it/sec | Loss 0.2000 | Reco 0.2000 | Nsdr 4.110
# [10-12 20:41:59][demucs.solver][INFO] - Valid | Epoch 3 | 6/14 | 0.30 it/sec | Loss 0.1974 | Reco 0.1974 | Nsdr 4.339
# [10-12 20:42:05][demucs.solver][INFO] - Valid | Epoch 3 | 9/14 | 0.34 it/sec | Loss 0.1956 | Reco 0.1956 | Nsdr 4.154
# [10-12 20:42:12][demucs.solver][INFO] - Valid | Epoch 3 | 12/14 | 0.36 it/sec | Loss 0.1914 | Reco 0.1914 | Nsdr 4.482
# [10-12 20:42:14][demucs.solver][INFO] - Valid Summary | Epoch 3 | Loss=0.1980 | Reco=0.1980 | Nsdr=4.355 | Best=0.1980 | Bname=main
# [10-12 20:42:14][demucs.solver][INFO] - New best valid loss 0.1980
# [10-12 20:42:18][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 20:42:18][demucs.solver][INFO] - Training...
# [10-12 20:58:28][demucs.solver][INFO] - Train | Epoch 4 | 295/1180 | 0.31 it/sec | Loss 0.1264 | Reco 0.1264 | Grad 0.0643
# [10-12 21:14:40][demucs.solver][INFO] - Train | Epoch 4 | 590/1180 | 0.30 it/sec | Loss 0.1256 | Reco 0.1256 | Grad 0.0640
# [10-12 21:30:37][demucs.solver][INFO] - Train | Epoch 4 | 885/1180 | 0.31 it/sec | Loss 0.1249 | Reco 0.1249 | Grad 0.0633
# [10-12 21:46:41][demucs.solver][INFO] - Train Summary | Epoch 4 | Loss=0.1236 | Reco=0.1236 | Grad=0.0628
# [10-12 21:46:41][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 21:46:41][demucs.solver][INFO] - Cross validation...
# [10-12 21:46:56][demucs.solver][INFO] - Valid | Epoch 4 | 3/14 | 0.27 it/sec | Loss 0.1940 | Reco 0.1940 | Nsdr 4.402
# [10-12 21:47:05][demucs.solver][INFO] - Valid | Epoch 4 | 6/14 | 0.30 it/sec | Loss 0.1922 | Reco 0.1922 | Nsdr 4.568
# [10-12 21:47:11][demucs.solver][INFO] - Valid | Epoch 4 | 9/14 | 0.34 it/sec | Loss 0.1897 | Reco 0.1897 | Nsdr 4.407
# [10-12 21:47:18][demucs.solver][INFO] - Valid | Epoch 4 | 12/14 | 0.36 it/sec | Loss 0.1857 | Reco 0.1857 | Nsdr 4.709
# [10-12 21:47:20][demucs.solver][INFO] - Valid Summary | Epoch 4 | Loss=0.1917 | Reco=0.1917 | Nsdr=4.600 | Best=0.1917 | Bname=main
# [10-12 21:47:20][demucs.solver][INFO] - New best valid loss 0.1917
# [10-12 21:47:25][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 21:47:25][demucs.solver][INFO] - Training...
# [10-12 22:03:37][demucs.solver][INFO] - Train | Epoch 5 | 295/1180 | 0.30 it/sec | Loss 0.1208 | Reco 0.1208 | Grad 0.0618
# [10-12 22:19:47][demucs.solver][INFO] - Train | Epoch 5 | 590/1180 | 0.30 it/sec | Loss 0.1198 | Reco 0.1198 | Grad 0.0615
# [10-12 22:35:47][demucs.solver][INFO] - Train | Epoch 5 | 885/1180 | 0.31 it/sec | Loss 0.1189 | Reco 0.1189 | Grad 0.0613
# [10-12 22:51:37][demucs.solver][INFO] - Train Summary | Epoch 5 | Loss=0.1181 | Reco=0.1181 | Grad=0.0614
# [10-12 22:51:37][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 22:51:37][demucs.solver][INFO] - Cross validation...
# [10-12 22:51:52][demucs.solver][INFO] - Valid | Epoch 5 | 3/14 | 0.26 it/sec | Loss 0.1948 | Reco 0.1948 | Nsdr 4.319
# [10-12 22:52:01][demucs.solver][INFO] - Valid | Epoch 5 | 6/14 | 0.30 it/sec | Loss 0.1906 | Reco 0.1906 | Nsdr 4.545
# [10-12 22:52:07][demucs.solver][INFO] - Valid | Epoch 5 | 9/14 | 0.33 it/sec | Loss 0.1885 | Reco 0.1885 | Nsdr 4.386
# [10-12 22:52:14][demucs.solver][INFO] - Valid | Epoch 5 | 12/14 | 0.36 it/sec | Loss 0.1850 | Reco 0.1850 | Nsdr 4.687
# [10-12 22:52:16][demucs.solver][INFO] - Valid Summary | Epoch 5 | Loss=0.1913 | Reco=0.1913 | Nsdr=4.576 | Best=0.1913 | Bname=main
# [10-12 22:52:16][demucs.solver][INFO] - New best valid loss 0.1913
# [10-12 22:52:20][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 22:52:20][demucs.solver][INFO] - Training...
# [10-12 23:08:35][demucs.solver][INFO] - Train | Epoch 6 | 295/1180 | 0.30 it/sec | Loss 0.1142 | Reco 0.1142 | Grad 0.0595
# [10-12 23:24:27][demucs.solver][INFO] - Train | Epoch 6 | 590/1180 | 0.31 it/sec | Loss 0.1150 | Reco 0.1150 | Grad 0.0618
# [10-12 23:40:32][demucs.solver][INFO] - Train | Epoch 6 | 885/1180 | 0.31 it/sec | Loss 0.1148 | Reco 0.1148 | Grad 0.0604
# [10-12 23:56:28][demucs.solver][INFO] - Train Summary | Epoch 6 | Loss=0.1143 | Reco=0.1143 | Grad=0.0597
# [10-12 23:56:28][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 23:56:28][demucs.solver][INFO] - Cross validation...
# [10-12 23:56:44][demucs.solver][INFO] - Valid | Epoch 6 | 3/14 | 0.27 it/sec | Loss 0.1870 | Reco 0.1870 | Nsdr 4.745
# [10-12 23:56:52][demucs.solver][INFO] - Valid | Epoch 6 | 6/14 | 0.30 it/sec | Loss 0.1850 | Reco 0.1850 | Nsdr 4.896
# [10-12 23:56:58][demucs.solver][INFO] - Valid | Epoch 6 | 9/14 | 0.34 it/sec | Loss 0.1840 | Reco 0.1840 | Nsdr 4.636
# [10-12 23:57:05][demucs.solver][INFO] - Valid | Epoch 6 | 12/14 | 0.35 it/sec | Loss 0.1806 | Reco 0.1806 | Nsdr 4.943
# [10-12 23:57:07][demucs.solver][INFO] - Valid Summary | Epoch 6 | Loss=0.1860 | Reco=0.1860 | Nsdr=4.836 | Best=0.1860 | Bname=main
# [10-12 23:57:07][demucs.solver][INFO] - New best valid loss 0.1860
# [10-12 23:57:12][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-12 23:57:12][demucs.solver][INFO] - Training...
# [10-13 00:13:17][demucs.solver][INFO] - Train | Epoch 7 | 295/1180 | 0.31 it/sec | Loss 0.1134 | Reco 0.1134 | Grad 0.0576
# [10-13 00:29:16][demucs.solver][INFO] - Train | Epoch 7 | 590/1180 | 0.31 it/sec | Loss 0.1123 | Reco 0.1123 | Grad 0.0588
# [10-13 00:45:31][demucs.solver][INFO] - Train | Epoch 7 | 885/1180 | 0.31 it/sec | Loss 0.1116 | Reco 0.1116 | Grad 0.0595
# [10-13 01:01:16][demucs.solver][INFO] - Train Summary | Epoch 7 | Loss=0.1113 | Reco=0.1113 | Grad=0.0591
# [10-13 01:01:16][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 01:01:16][demucs.solver][INFO] - Cross validation...
# [10-13 01:01:31][demucs.solver][INFO] - Valid | Epoch 7 | 3/14 | 0.27 it/sec | Loss 0.1831 | Reco 0.1831 | Nsdr 4.816
# [10-13 01:01:39][demucs.solver][INFO] - Valid | Epoch 7 | 6/14 | 0.30 it/sec | Loss 0.1809 | Reco 0.1809 | Nsdr 4.996
# [10-13 01:01:46][demucs.solver][INFO] - Valid | Epoch 7 | 9/14 | 0.34 it/sec | Loss 0.1809 | Reco 0.1809 | Nsdr 4.689
# [10-13 01:01:53][demucs.solver][INFO] - Valid | Epoch 7 | 12/14 | 0.36 it/sec | Loss 0.1772 | Reco 0.1772 | Nsdr 5.020
# [10-13 01:01:55][demucs.solver][INFO] - Valid Summary | Epoch 7 | Loss=0.1824 | Reco=0.1824 | Nsdr=4.936 | Best=0.1824 | Bname=main
# [10-13 01:01:55][demucs.solver][INFO] - New best valid loss 0.1824
# [10-13 01:01:59][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 01:01:59][demucs.solver][INFO] - Training...
# [10-13 01:17:57][demucs.solver][INFO] - Train | Epoch 8 | 295/1180 | 0.31 it/sec | Loss 0.1102 | Reco 0.1102 | Grad 0.0603
# [10-13 01:33:49][demucs.solver][INFO] - Train | Epoch 8 | 590/1180 | 0.31 it/sec | Loss 0.1090 | Reco 0.1090 | Grad 0.0612
# [10-13 01:49:58][demucs.solver][INFO] - Train | Epoch 8 | 885/1180 | 0.31 it/sec | Loss 0.1096 | Reco 0.1096 | Grad 0.0611
# [10-13 02:05:45][demucs.solver][INFO] - Train Summary | Epoch 8 | Loss=0.1091 | Reco=0.1091 | Grad=0.0604
# [10-13 02:05:45][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 02:05:45][demucs.solver][INFO] - Cross validation...
# [10-13 02:06:01][demucs.solver][INFO] - Valid | Epoch 8 | 3/14 | 0.27 it/sec | Loss 0.1816 | Reco 0.1816 | Nsdr 4.938
# [10-13 02:06:09][demucs.solver][INFO] - Valid | Epoch 8 | 6/14 | 0.30 it/sec | Loss 0.1787 | Reco 0.1787 | Nsdr 5.148
# [10-13 02:06:15][demucs.solver][INFO] - Valid | Epoch 8 | 9/14 | 0.34 it/sec | Loss 0.1788 | Reco 0.1788 | Nsdr 4.890
# [10-13 02:06:22][demucs.solver][INFO] - Valid | Epoch 8 | 12/14 | 0.36 it/sec | Loss 0.1744 | Reco 0.1744 | Nsdr 5.225
# [10-13 02:06:24][demucs.solver][INFO] - Valid Summary | Epoch 8 | Loss=0.1795 | Reco=0.1795 | Nsdr=5.121 | Best=0.1795 | Bname=main
# [10-13 02:06:24][demucs.solver][INFO] - New best valid loss 0.1795
# [10-13 02:06:29][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 02:06:29][demucs.solver][INFO] - Training...
# [10-13 02:22:43][demucs.solver][INFO] - Train | Epoch 9 | 295/1180 | 0.30 it/sec | Loss 0.1062 | Reco 0.1062 | Grad 0.0557
# [10-13 02:38:39][demucs.solver][INFO] - Train | Epoch 9 | 590/1180 | 0.31 it/sec | Loss 0.1064 | Reco 0.1064 | Grad 0.0574
# [10-13 02:54:39][demucs.solver][INFO] - Train | Epoch 9 | 885/1180 | 0.31 it/sec | Loss 0.1065 | Reco 0.1065 | Grad 0.0575
# [10-13 03:10:36][demucs.solver][INFO] - Train Summary | Epoch 9 | Loss=0.1066 | Reco=0.1066 | Grad=0.0580
# [10-13 03:10:36][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 03:10:36][demucs.solver][INFO] - Cross validation...
# [10-13 03:10:51][demucs.solver][INFO] - Valid | Epoch 9 | 3/14 | 0.26 it/sec | Loss 0.1815 | Reco 0.1815 | Nsdr 4.984
# [10-13 03:11:00][demucs.solver][INFO] - Valid | Epoch 9 | 6/14 | 0.29 it/sec | Loss 0.1764 | Reco 0.1764 | Nsdr 5.254
# [10-13 03:11:06][demucs.solver][INFO] - Valid | Epoch 9 | 9/14 | 0.33 it/sec | Loss 0.1771 | Reco 0.1771 | Nsdr 4.934
# [10-13 03:11:13][demucs.solver][INFO] - Valid | Epoch 9 | 12/14 | 0.35 it/sec | Loss 0.1737 | Reco 0.1737 | Nsdr 5.239
# [10-13 03:11:15][demucs.solver][INFO] - Valid Summary | Epoch 9 | Loss=0.1782 | Reco=0.1782 | Nsdr=5.183 | Best=0.1782 | Bname=main
# [10-13 03:11:15][demucs.solver][INFO] - New best valid loss 0.1782
# [10-13 03:11:19][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 03:11:19][demucs.solver][INFO] - Training...
# [10-13 03:27:41][demucs.solver][INFO] - Train | Epoch 10 | 295/1180 | 0.30 it/sec | Loss 0.1057 | Reco 0.1057 | Grad 0.0577
# [10-13 03:43:48][demucs.solver][INFO] - Train | Epoch 10 | 590/1180 | 0.30 it/sec | Loss 0.1054 | Reco 0.1054 | Grad 0.0577
# [10-13 03:59:52][demucs.solver][INFO] - Train | Epoch 10 | 885/1180 | 0.30 it/sec | Loss 0.1051 | Reco 0.1051 | Grad 0.0585
# [10-13 04:15:47][demucs.solver][INFO] - Train Summary | Epoch 10 | Loss=0.1047 | Reco=0.1047 | Grad=0.0590
# [10-13 04:15:47][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 04:15:47][demucs.solver][INFO] - Cross validation...
# [10-13 04:16:02][demucs.solver][INFO] - Valid | Epoch 10 | 3/14 | 0.26 it/sec | Loss 0.1800 | Reco 0.1800 | Nsdr 5.057
# [10-13 04:16:10][demucs.solver][INFO] - Valid | Epoch 10 | 6/14 | 0.30 it/sec | Loss 0.1749 | Reco 0.1749 | Nsdr 5.324
# [10-13 04:16:16][demucs.solver][INFO] - Valid | Epoch 10 | 9/14 | 0.34 it/sec | Loss 0.1751 | Reco 0.1751 | Nsdr 5.047
# [10-13 04:16:23][demucs.solver][INFO] - Valid | Epoch 10 | 12/14 | 0.36 it/sec | Loss 0.1716 | Reco 0.1716 | Nsdr 5.350
# [10-13 04:16:25][demucs.solver][INFO] - Valid Summary | Epoch 10 | Loss=0.1766 | Reco=0.1766 | Nsdr=5.246 | Best=0.1766 | Bname=main
# [10-13 04:16:25][demucs.solver][INFO] - New best valid loss 0.1766
# [10-13 04:16:30][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 04:16:30][demucs.solver][INFO] - Training...
# [10-13 04:32:39][demucs.solver][INFO] - Train | Epoch 11 | 295/1180 | 0.31 it/sec | Loss 0.1050 | Reco 0.1050 | Grad 0.0588
# [10-13 04:48:43][demucs.solver][INFO] - Train | Epoch 11 | 590/1180 | 0.31 it/sec | Loss 0.1048 | Reco 0.1048 | Grad 0.0619
# [10-13 05:04:51][demucs.solver][INFO] - Train | Epoch 11 | 885/1180 | 0.31 it/sec | Loss 0.1043 | Reco 0.1043 | Grad 0.0607
# [10-13 05:20:43][demucs.solver][INFO] - Train Summary | Epoch 11 | Loss=0.1037 | Reco=0.1037 | Grad=0.0595
# [10-13 05:20:43][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 05:20:43][demucs.solver][INFO] - Cross validation...
# [10-13 05:20:58][demucs.solver][INFO] - Valid | Epoch 11 | 3/14 | 0.26 it/sec | Loss 0.1810 | Reco 0.1810 | Nsdr 4.982
# [10-13 05:21:07][demucs.solver][INFO] - Valid | Epoch 11 | 6/14 | 0.29 it/sec | Loss 0.1796 | Reco 0.1796 | Nsdr 5.160
# [10-13 05:21:13][demucs.solver][INFO] - Valid | Epoch 11 | 9/14 | 0.33 it/sec | Loss 0.1780 | Reco 0.1780 | Nsdr 4.903
# [10-13 05:21:20][demucs.solver][INFO] - Valid | Epoch 11 | 12/14 | 0.35 it/sec | Loss 0.1737 | Reco 0.1737 | Nsdr 5.244
# [10-13 05:21:22][demucs.solver][INFO] - Valid Summary | Epoch 11 | Loss=0.1784 | Reco=0.1784 | Nsdr=5.167 | Best=0.1766 | Bname=main
# [10-13 05:21:25][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 05:21:25][demucs.solver][INFO] - Training...
# [10-13 05:37:28][demucs.solver][INFO] - Train | Epoch 12 | 295/1180 | 0.31 it/sec | Loss 0.1021 | Reco 0.1021 | Grad 0.0560
# [10-13 05:53:16][demucs.solver][INFO] - Train | Epoch 12 | 590/1180 | 0.31 it/sec | Loss 0.1010 | Reco 0.1010 | Grad 0.0562
# [10-13 06:09:11][demucs.solver][INFO] - Train | Epoch 12 | 885/1180 | 0.31 it/sec | Loss 0.1021 | Reco 0.1021 | Grad 0.0572
# [10-13 06:25:23][demucs.solver][INFO] - Train Summary | Epoch 12 | Loss=0.1018 | Reco=0.1018 | Grad=0.0569
# [10-13 06:25:23][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 06:25:23][demucs.solver][INFO] - Cross validation...
# [10-13 06:25:38][demucs.solver][INFO] - Valid | Epoch 12 | 3/14 | 0.26 it/sec | Loss 0.1747 | Reco 0.1747 | Nsdr 5.286
# [10-13 06:25:46][demucs.solver][INFO] - Valid | Epoch 12 | 6/14 | 0.30 it/sec | Loss 0.1726 | Reco 0.1726 | Nsdr 5.457
# [10-13 06:25:52][demucs.solver][INFO] - Valid | Epoch 12 | 9/14 | 0.34 it/sec | Loss 0.1743 | Reco 0.1743 | Nsdr 5.102
# [10-13 06:25:59][demucs.solver][INFO] - Valid | Epoch 12 | 12/14 | 0.36 it/sec | Loss 0.1704 | Reco 0.1704 | Nsdr 5.418
# [10-13 06:26:01][demucs.solver][INFO] - Valid Summary | Epoch 12 | Loss=0.1751 | Reco=0.1751 | Nsdr=5.340 | Best=0.1751 | Bname=main
# [10-13 06:26:01][demucs.solver][INFO] - New best valid loss 0.1751
# [10-13 06:26:06][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 06:26:06][demucs.solver][INFO] - Training...
# [10-13 06:42:35][demucs.solver][INFO] - Train | Epoch 13 | 295/1180 | 0.30 it/sec | Loss 0.1018 | Reco 0.1018 | Grad 0.0597
# [10-13 06:58:17][demucs.solver][INFO] - Train | Epoch 13 | 590/1180 | 0.31 it/sec | Loss 0.1018 | Reco 0.1018 | Grad 0.0588
# [10-13 07:14:19][demucs.solver][INFO] - Train | Epoch 13 | 885/1180 | 0.31 it/sec | Loss 0.1010 | Reco 0.1010 | Grad 0.0587
# [10-13 07:30:06][demucs.solver][INFO] - Train Summary | Epoch 13 | Loss=0.1008 | Reco=0.1008 | Grad=0.0587
# [10-13 07:30:06][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 07:30:06][demucs.solver][INFO] - Cross validation...
# [10-13 07:30:21][demucs.solver][INFO] - Valid | Epoch 13 | 3/14 | 0.27 it/sec | Loss 0.1744 | Reco 0.1744 | Nsdr 5.312
# [10-13 07:30:30][demucs.solver][INFO] - Valid | Epoch 13 | 6/14 | 0.30 it/sec | Loss 0.1738 | Reco 0.1738 | Nsdr 5.405
# [10-13 07:30:36][demucs.solver][INFO] - Valid | Epoch 13 | 9/14 | 0.34 it/sec | Loss 0.1742 | Reco 0.1742 | Nsdr 5.080
# [10-13 07:30:43][demucs.solver][INFO] - Valid | Epoch 13 | 12/14 | 0.36 it/sec | Loss 0.1708 | Reco 0.1708 | Nsdr 5.389
# [10-13 07:30:45][demucs.solver][INFO] - Valid Summary | Epoch 13 | Loss=0.1750 | Reco=0.1750 | Nsdr=5.329 | Best=0.1750 | Bname=main
# [10-13 07:30:45][demucs.solver][INFO] - New best valid loss 0.1750
# [10-13 07:30:50][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 07:30:50][demucs.solver][INFO] - Training...
# [10-13 07:46:55][demucs.solver][INFO] - Train | Epoch 14 | 295/1180 | 0.31 it/sec | Loss 0.0990 | Reco 0.0990 | Grad 0.0559
# [10-13 08:02:41][demucs.solver][INFO] - Train | Epoch 14 | 590/1180 | 0.31 it/sec | Loss 0.0998 | Reco 0.0998 | Grad 0.0589
# [10-13 08:18:34][demucs.solver][INFO] - Train | Epoch 14 | 885/1180 | 0.31 it/sec | Loss 0.0998 | Reco 0.0998 | Grad 0.0593
# [10-13 08:34:32][demucs.solver][INFO] - Train Summary | Epoch 14 | Loss=0.0998 | Reco=0.0998 | Grad=0.0594
# [10-13 08:34:32][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 08:34:32][demucs.solver][INFO] - Cross validation...
# [10-13 08:34:48][demucs.solver][INFO] - Valid | Epoch 14 | 3/14 | 0.26 it/sec | Loss 0.1741 | Reco 0.1741 | Nsdr 5.392
# [10-13 08:34:56][demucs.solver][INFO] - Valid | Epoch 14 | 6/14 | 0.30 it/sec | Loss 0.1740 | Reco 0.1740 | Nsdr 5.482
# [10-13 08:35:02][demucs.solver][INFO] - Valid | Epoch 14 | 9/14 | 0.34 it/sec | Loss 0.1759 | Reco 0.1759 | Nsdr 5.115
# [10-13 08:35:09][demucs.solver][INFO] - Valid | Epoch 14 | 12/14 | 0.36 it/sec | Loss 0.1716 | Reco 0.1716 | Nsdr 5.443
# [10-13 08:35:11][demucs.solver][INFO] - Valid Summary | Epoch 14 | Loss=0.1762 | Reco=0.1762 | Nsdr=5.371 | Best=0.1750 | Bname=main
# [10-13 08:35:14][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 08:35:14][demucs.solver][INFO] - Training...
# [10-13 08:51:28][demucs.solver][INFO] - Train | Epoch 15 | 295/1180 | 0.30 it/sec | Loss 0.0993 | Reco 0.0993 | Grad 0.0579
# [10-13 09:07:39][demucs.solver][INFO] - Train | Epoch 15 | 590/1180 | 0.30 it/sec | Loss 0.0980 | Reco 0.0980 | Grad 0.0566
# [10-13 09:23:37][demucs.solver][INFO] - Train | Epoch 15 | 885/1180 | 0.31 it/sec | Loss 0.0982 | Reco 0.0982 | Grad 0.0570
# [10-13 09:39:26][demucs.solver][INFO] - Train Summary | Epoch 15 | Loss=0.0984 | Reco=0.0984 | Grad=0.0576
# [10-13 09:39:26][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 09:39:26][demucs.solver][INFO] - Cross validation...
# [10-13 09:39:41][demucs.solver][INFO] - Valid | Epoch 15 | 3/14 | 0.27 it/sec | Loss 0.1749 | Reco 0.1749 | Nsdr 5.345
# [10-13 09:39:50][demucs.solver][INFO] - Valid | Epoch 15 | 6/14 | 0.30 it/sec | Loss 0.1714 | Reco 0.1714 | Nsdr 5.535
# [10-13 09:39:56][demucs.solver][INFO] - Valid | Epoch 15 | 9/14 | 0.34 it/sec | Loss 0.1718 | Reco 0.1718 | Nsdr 5.217
# [10-13 09:40:03][demucs.solver][INFO] - Valid | Epoch 15 | 12/14 | 0.36 it/sec | Loss 0.1693 | Reco 0.1693 | Nsdr 5.487
# [10-13 09:40:05][demucs.solver][INFO] - Valid Summary | Epoch 15 | Loss=0.1748 | Reco=0.1748 | Nsdr=5.375 | Best=0.1748 | Bname=main
# [10-13 09:40:05][demucs.solver][INFO] - New best valid loss 0.1748
# [10-13 09:40:09][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 09:40:09][demucs.solver][INFO] - Training...
# [10-13 09:56:14][demucs.solver][INFO] - Train | Epoch 16 | 295/1180 | 0.31 it/sec | Loss 0.0981 | Reco 0.0981 | Grad 0.0564
# [10-13 10:12:22][demucs.solver][INFO] - Train | Epoch 16 | 590/1180 | 0.31 it/sec | Loss 0.0978 | Reco 0.0978 | Grad 0.0565
# [10-13 10:28:22][demucs.solver][INFO] - Train | Epoch 16 | 885/1180 | 0.31 it/sec | Loss 0.0976 | Reco 0.0976 | Grad 0.0564
# [10-13 10:44:31][demucs.solver][INFO] - Train Summary | Epoch 16 | Loss=0.0976 | Reco=0.0976 | Grad=0.0568
# [10-13 10:44:31][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 10:44:31][demucs.solver][INFO] - Cross validation...
# [10-13 10:44:47][demucs.solver][INFO] - Valid | Epoch 16 | 3/14 | 0.27 it/sec | Loss 0.1743 | Reco 0.1743 | Nsdr 5.377
# [10-13 10:44:55][demucs.solver][INFO] - Valid | Epoch 16 | 6/14 | 0.30 it/sec | Loss 0.1733 | Reco 0.1733 | Nsdr 5.510
# [10-13 10:45:01][demucs.solver][INFO] - Valid | Epoch 16 | 9/14 | 0.34 it/sec | Loss 0.1735 | Reco 0.1735 | Nsdr 5.212
# [10-13 10:45:08][demucs.solver][INFO] - Valid | Epoch 16 | 12/14 | 0.36 it/sec | Loss 0.1693 | Reco 0.1693 | Nsdr 5.545
# [10-13 10:45:10][demucs.solver][INFO] - Valid Summary | Epoch 16 | Loss=0.1735 | Reco=0.1735 | Nsdr=5.476 | Best=0.1735 | Bname=main
# [10-13 10:45:10][demucs.solver][INFO] - New best valid loss 0.1735
# [10-13 10:45:17][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 10:45:17][demucs.solver][INFO] - Training...
# [10-13 11:01:21][demucs.solver][INFO] - Train | Epoch 17 | 295/1180 | 0.31 it/sec | Loss 0.0953 | Reco 0.0953 | Grad 0.0546
# [10-13 11:17:16][demucs.solver][INFO] - Train | Epoch 17 | 590/1180 | 0.31 it/sec | Loss 0.0960 | Reco 0.0960 | Grad 0.0557
# [10-13 11:33:31][demucs.solver][INFO] - Train | Epoch 17 | 885/1180 | 0.31 it/sec | Loss 0.0960 | Reco 0.0960 | Grad 0.0565
# [10-13 11:49:28][demucs.solver][INFO] - Train Summary | Epoch 17 | Loss=0.0967 | Reco=0.0967 | Grad=0.0568
# [10-13 11:49:28][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 11:49:28][demucs.solver][INFO] - Cross validation...
# [10-13 11:49:43][demucs.solver][INFO] - Valid | Epoch 17 | 3/14 | 0.26 it/sec | Loss 0.1699 | Reco 0.1699 | Nsdr 5.538
# [10-13 11:49:51][demucs.solver][INFO] - Valid | Epoch 17 | 6/14 | 0.30 it/sec | Loss 0.1666 | Reco 0.1666 | Nsdr 5.741
# [10-13 11:49:57][demucs.solver][INFO] - Valid | Epoch 17 | 9/14 | 0.34 it/sec | Loss 0.1674 | Reco 0.1674 | Nsdr 5.414
# [10-13 11:50:04][demucs.solver][INFO] - Valid | Epoch 17 | 12/14 | 0.36 it/sec | Loss 0.1648 | Reco 0.1648 | Nsdr 5.710
# [10-13 11:50:06][demucs.solver][INFO] - Valid Summary | Epoch 17 | Loss=0.1692 | Reco=0.1692 | Nsdr=5.650 | Best=0.1692 | Bname=main
# [10-13 11:50:06][demucs.solver][INFO] - New best valid loss 0.1692
# [10-13 11:50:11][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 11:50:11][demucs.solver][INFO] - Training...
# [10-13 12:06:33][demucs.solver][INFO] - Train | Epoch 18 | 295/1180 | 0.30 it/sec | Loss 0.0951 | Reco 0.0951 | Grad 0.0568
# [10-13 12:22:43][demucs.solver][INFO] - Train | Epoch 18 | 590/1180 | 0.30 it/sec | Loss 0.0958 | Reco 0.0958 | Grad 0.0558
# [10-13 12:38:50][demucs.solver][INFO] - Train | Epoch 18 | 885/1180 | 0.30 it/sec | Loss 0.0961 | Reco 0.0961 | Grad 0.0574
# [10-13 12:54:35][demucs.solver][INFO] - Train Summary | Epoch 18 | Loss=0.0959 | Reco=0.0959 | Grad=0.0570
# [10-13 12:54:35][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 12:54:35][demucs.solver][INFO] - Cross validation...
# [10-13 12:54:50][demucs.solver][INFO] - Valid | Epoch 18 | 3/14 | 0.27 it/sec | Loss 0.1723 | Reco 0.1723 | Nsdr 5.434
# [10-13 12:54:58][demucs.solver][INFO] - Valid | Epoch 18 | 6/14 | 0.30 it/sec | Loss 0.1689 | Reco 0.1689 | Nsdr 5.634
# [10-13 12:55:04][demucs.solver][INFO] - Valid | Epoch 18 | 9/14 | 0.34 it/sec | Loss 0.1691 | Reco 0.1691 | Nsdr 5.328
# [10-13 12:55:11][demucs.solver][INFO] - Valid | Epoch 18 | 12/14 | 0.36 it/sec | Loss 0.1665 | Reco 0.1665 | Nsdr 5.595
# [10-13 12:55:13][demucs.solver][INFO] - Valid Summary | Epoch 18 | Loss=0.1719 | Reco=0.1719 | Nsdr=5.482 | Best=0.1692 | Bname=main
# [10-13 12:55:17][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 12:55:17][demucs.solver][INFO] - Training...
# [10-13 13:11:34][demucs.solver][INFO] - Train | Epoch 19 | 295/1180 | 0.30 it/sec | Loss 0.0957 | Reco 0.0957 | Grad 0.0557
# [10-13 13:27:34][demucs.solver][INFO] - Train | Epoch 19 | 590/1180 | 0.31 it/sec | Loss 0.0949 | Reco 0.0949 | Grad 0.0552
# [10-13 13:43:34][demucs.solver][INFO] - Train | Epoch 19 | 885/1180 | 0.31 it/sec | Loss 0.0947 | Reco 0.0947 | Grad 0.0550
# [10-13 13:59:28][demucs.solver][INFO] - Train Summary | Epoch 19 | Loss=0.0948 | Reco=0.0948 | Grad=0.0551
# [10-13 13:59:28][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 13:59:28][demucs.solver][INFO] - Cross validation...
# [10-13 13:59:43][demucs.solver][INFO] - Valid | Epoch 19 | 3/14 | 0.26 it/sec | Loss 0.1780 | Reco 0.1780 | Nsdr 5.215
# [10-13 13:59:52][demucs.solver][INFO] - Valid | Epoch 19 | 6/14 | 0.30 it/sec | Loss 0.1739 | Reco 0.1739 | Nsdr 5.482
# [10-13 13:59:58][demucs.solver][INFO] - Valid | Epoch 19 | 9/14 | 0.34 it/sec | Loss 0.1771 | Reco 0.1771 | Nsdr 5.083
# [10-13 14:00:05][demucs.solver][INFO] - Valid | Epoch 19 | 12/14 | 0.36 it/sec | Loss 0.1735 | Reco 0.1735 | Nsdr 5.384
# [10-13 14:00:07][demucs.solver][INFO] - Valid Summary | Epoch 19 | Loss=0.1777 | Reco=0.1777 | Nsdr=5.330 | Best=0.1692 | Bname=main
# [10-13 14:00:10][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 14:00:10][demucs.solver][INFO] - Training...
# [10-13 14:16:15][demucs.solver][INFO] - Train | Epoch 20 | 295/1180 | 0.31 it/sec | Loss 0.0933 | Reco 0.0933 | Grad 0.0550
# [10-13 14:32:18][demucs.solver][INFO] - Train | Epoch 20 | 590/1180 | 0.31 it/sec | Loss 0.0940 | Reco 0.0940 | Grad 0.0553
# [10-13 14:48:13][demucs.solver][INFO] - Train | Epoch 20 | 885/1180 | 0.31 it/sec | Loss 0.0941 | Reco 0.0941 | Grad 0.0554
# [10-13 15:03:58][demucs.solver][INFO] - Train Summary | Epoch 20 | Loss=0.0943 | Reco=0.0943 | Grad=0.0552
# [10-13 15:03:58][demucs.solver][INFO] - ----------------------------------------------------------------------
# [10-13 15:03:58][demucs.solver][INFO] - Cross validation...
# [10-13 15:04:13][demucs.solver][INFO] - Valid | Epoch 20 | 3/14 | 0.26 it/sec | Loss 0.1702 | Reco 0.1702 | Nsdr 5.651
# [10-13 15:04:22][demucs.solver][INFO] - Valid | Epoch 20 | 6/14 | 0.30 it/sec | Loss 0.1671 | Reco 0.1671 | Nsdr 5.816
# [10-13 15:04:28][demucs.solver][INFO] - Valid | Epoch 20 | 9/14 | 0.34 it/sec | Loss 0.1680 | Reco 0.1680 | Nsdr 5.455
# [10-13 15:04:35][demucs.solver][INFO] - Valid | Epoch 20 | 12/14 | 0.36 it/sec | Loss 0.1648 | Reco 0.1648 | Nsdr 5.746
# [10-13 15:04:37][demucs.solver][INFO] - Valid Summary | Epoch 20 | Loss=0.1691 | Reco=0.1691 | Nsdr=5.680 | Best=0.1691 | Bname=main
# [10-13 15:04:37][demucs.solver][INFO] - New best valid loss 0.1691
# Executor: All workers completed successfully

# %%
# @title 5.2 Continue training from checkpoint (Assuming you stopped halfway)

#@markdown Go to /content/drive/MyDrive/demucs_outputs/xps to find your model XP signature (e.g 97d170e1)
signature = "" # @param {"type":"string","placeholder":"Insert XP signature (e.g 97d170e1)"}
# !dora run -d -f {signature}

# %%
# @title 6. Export model! (After successfully exporting, your model's .th file will be located at /content/MCS14_FIT3162_SINGING_VIDEO_SEPERATION/demucs/release_models)
#@markdown Go to /content/drive/MyDrive/demucs_outputs/xps to find your model XP signature (e.g 97d170e1)
signature = "" # @param {"type":"string","placeholder":"Insert XP signature (e.g 97d170e1)"}

# !python3 -m tools.export {signature}
# Out:
# INFO:__main__:Handling d7014c1b/batch_size=16 dem.channels=32 dem.depth=4 dse.segment=5 epochs=20 opt.lr=0.0005
# INFO:dora.distrib:world_size is 1, skipping init.
# INFO:demucs.train:train/valid set size: 18884 14
# INFO:demucs.solver:Loading checkpoint model: /content/drive/MyDrive/demucs_outputs/xps/d7014c1b/checkpoint.th

# %% [markdown]
# # To test the model, create 3 folders in your My Drive: **Input, Output, Model**.
# ## Find your model's .th file located in /content/MCS14_FIT3162_SINGING_VIDEO_SEPERATION/demucs/release_models, and upload it in the **Model** folder.
# ## Upload a test song (.wav or .mp3) in the **Input** folder.
# ## Then run the code below, the separated track will be located in the **Output** folder.

# %%
# @title 7. Test the model

#@markdown Go to /content/drive/MyDrive/Model to find your model XP signature (e.g 97d170e1)
signature = "d7014c1b" # @param {"type":"string","placeholder":"Insert XP signature (e.g 97d170e1)"}

import io
from pathlib import Path
import select
from shutil import rmtree
import subprocess as sp
import sys
from typing import Dict, Tuple, Optional, IO

from google.colab import files

# Define the input and output paths
in_path = '/content/drive/MyDrive/Input'
out_path = '/content/drive/MyDrive/Output'
# Define the Demucs model to use
model = signature # Put here the name of the model of the .th file in your case 'user-trained'

extensions = set("wav mp3".split())

def find_files(in_path):
    out = []
    for file in Path(in_path).iterdir():
        if file.suffix.lower().lstrip(".") in extensions:
            out.append(file)
    return out

def copy_process_streams(process: sp.Popen):
    def raw(stream: Optional[IO[bytes]]) -> IO[bytes]:
        assert stream is not None
        if isinstance(stream, io.BufferedIOBase):
            stream = stream.raw
        return stream

    p_stdout, p_stderr = raw(process.stdout), raw(process.stderr)
    stream_by_fd: Dict[int, Tuple[IO[bytes], io.StringIO, IO[str]]] = {
        p_stdout.fileno(): (p_stdout, sys.stdout),
        p_stderr.fileno(): (p_stderr, sys.stderr),
    }
    fds = list(stream_by_fd.keys())

    while fds:
        # `select` syscall will wait until one of the file descriptors has content.
        ready, _, _ = select.select(fds, [], [])
        for fd in ready:
            p_stream, std = stream_by_fd[fd]
            raw_buf = p_stream.read(2 ** 16)
            if not raw_buf:
                fds.remove(fd)
                continue
            buf = raw_buf.decode()
            std.write(buf)
            std.flush()

def separate(inp=None, outp=None):
    inp = inp or in_path
    outp = outp or out_path
    cmd = ["python3", "-m", "demucs.separate", "-o", str(outp), "-n", model, "--repo", "/content/drive/MyDrive/Model"]
    files = [str(f) for f in find_files(inp)]
    if not files:
        print(f"No valid audio files in {in_path}")
        return
    print("Going to separate the files:")
    print('\n'.join(files))
    print("With command: ", " ".join(cmd))
    p = sp.Popen(cmd + files, stdout=sp.PIPE, stderr=sp.PIPE)
    copy_process_streams(p)
    p.wait()
    if p.returncode != 0:
        print("Command failed, something went wrong.")

separate()

# %%
# @title 8. Evaluate the model
#@markdown Go to /content/MCS14_FIT3162_SINGING_VIDEO_SEPERATION/demucs/release_models to find your model XP signature (e.g 97d170e1)
signature = "d7014c1b" # @param {"type":"string","placeholder":"Insert XP signature (e.g 97d170e1)"}

# !python3 -m tools.test_pretrained --repo ./release_models -n {signature}
